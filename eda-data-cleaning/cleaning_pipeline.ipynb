# %%
import pandas as pd
import os

# paths
raw_path = "../assets/data/gps_sample.csv"
cleaned_path = "../assets/data/cleaned/gps_sample_cleaned.csv"

# show BEFORE cleaning
print("=== BEFORE CLEANING ===")
df_raw = pd.read_csv(raw_path)
print(df_raw.info())
print(df_raw.head())

# run cleaning script
print("\nRunning cleaning pipeline...\n")
# !python cleaning_pipeline.py

# show AFTER cleaning
print("\n=== AFTER CLEANING ===")
df_clean = pd.read_csv(cleaned_path)
print(df_clean.info())
print(df_clean.head())

print("\nRows before:", len(df_raw))
print("Rows after:", len(df_clean))
print("\nCleaning complete!")
